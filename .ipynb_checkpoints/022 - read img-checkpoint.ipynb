# %%
# read library
from skimage import io, img_as_float, img_as_ubyte
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
img = io.imread('images/Osteosarcoma_01.tif')

# %%
img
# Out:
# array([[[ 7, 69, 61],
#         [11, 73, 54],
#         [ 8, 76, 48],
#         ...,
#         [13, 54, 10],
#         [18, 59, 12],
#         [ 8, 70, 14]],
#
#        [[12, 77, 66],
#         [11, 74, 60],
#         [ 8, 76, 55],
#         ...,
#         [13, 46,  9],
#         [21, 77, 15],
#         [12, 85, 19]],
#
#        [[12, 86, 71],
#         [11, 84, 66],
#         [ 9, 78, 60],
#         ...,
#         [10, 33,  9],
#         [10, 54, 11],
#         [ 5, 56, 11]],
#
#        ...,
#
#        [[ 2, 34,  7],
#         [ 3, 27,  5],
#         [ 4, 28,  6],
#         ...,
#         [ 1,  0,  0],
#         [ 1,  0,  0],
#         [ 0,  1,  0]],
#
#        [[ 2, 35,  7],
#         [ 2, 30,  6],
#         [ 5, 27,  5],
#         ...,
#         [ 2,  3,  0],
#         [ 1,  2,  1],
#         [ 0,  0,  0]],
#
#        [[ 3, 35,  7],
#         [ 3, 39,  7],
#         [ 4, 35,  8],
#         ...,
#         [ 0,  1,  0],
#         [ 1,  2,  1],
#         [ 3,  1,  0]]], dtype=uint8)

# %%
print(img.shape)
print(f'height: {img.shape[0]}')
print(f'width: {img.shape[1]}')
print(f'channel: {img.shape[2]}') 
# if channel == 3 it's rgb image if, 1f no channel it's grayscal img
# Out:
# (1104, 1376, 3)
# height: 1104
# width: 1376
# channel: 3

# %%
img_float = img_as_float(img)
print(img_float)
# Out:
# [[[0.02745098 0.27058824 0.23921569]
#   [0.04313725 0.28627451 0.21176471]
#   [0.03137255 0.29803922 0.18823529]
#   ...
#   [0.05098039 0.21176471 0.03921569]
#   [0.07058824 0.23137255 0.04705882]
#   [0.03137255 0.2745098  0.05490196]]
#
#  [[0.04705882 0.30196078 0.25882353]
#   [0.04313725 0.29019608 0.23529412]
#   [0.03137255 0.29803922 0.21568627]
#   ...
#   [0.05098039 0.18039216 0.03529412]
#   [0.08235294 0.30196078 0.05882353]
#   [0.04705882 0.33333333 0.0745098 ]]
#
#  [[0.04705882 0.3372549  0.27843137]
#   [0.04313725 0.32941176 0.25882353]
#   [0.03529412 0.30588235 0.23529412]
#   ...
#   [0.03921569 0.12941176 0.03529412]
#   [0.03921569 0.21176471 0.04313725]
#   [0.01960784 0.21960784 0.04313725]]
#
#  ...
#
#  [[0.00784314 0.13333333 0.02745098]
#   [0.01176471 0.10588235 0.01960784]
#   [0.01568627 0.10980392 0.02352941]
#   ...
#   [0.00392157 0.         0.        ]
#   [0.00392157 0.         0.        ]
#   [0.         0.00392157 0.        ]]
#
# ...

# %%
img3 = img/255

# %%
img_float.shape
# Out:
# (1104, 1376, 3)

# %%
img2
# Out:
# array([[[ 7., 69., 61.],
#         [11., 73., 54.],
#         [ 8., 76., 48.],
#         ...,
#         [13., 54., 10.],
#         [18., 59., 12.],
#         [ 8., 70., 14.]],
#
#        [[12., 77., 66.],
#         [11., 74., 60.],
#         [ 8., 76., 55.],
#         ...,
#         [13., 46.,  9.],
#         [21., 77., 15.],
#         [12., 85., 19.]],
#
#        [[12., 86., 71.],
#         [11., 84., 66.],
#         [ 9., 78., 60.],
#         ...,
#         [10., 33.,  9.],
#         [10., 54., 11.],
#         [ 5., 56., 11.]],
#
#        ...,
#
#        [[ 2., 34.,  7.],
#         [ 3., 27.,  5.],
#         [ 4., 28.,  6.],
#         ...,
#         [ 1.,  0.,  0.],
#         [ 1.,  0.,  0.],
#         [ 0.,  1.,  0.]],
#
#        [[ 2., 35.,  7.],
#         [ 2., 30.,  6.],
#         [ 5., 27.,  5.],
#         ...,
#         [ 2.,  3.,  0.],
#         [ 1.,  2.,  1.],
#         [ 0.,  0.,  0.]],
#
#        [[ 3., 35.,  7.],
#         [ 3., 39.,  7.],
#         [ 4., 35.,  8.],
# ...

# %%
img2 = img.astype(np.float)
# Out:
# C:\Users\earth\AppData\Local\Temp\ipykernel_4656\572571300.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   img2 = img.astype(np.float)

# %%
plt.imshow(img)

# %%
plt.imshow(img_float)

# %%
plt.imshow(img2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(img3)

# %%
img_8bit = img_as_ubyte(img_float)

# %%
img
# Out:
# array([[[ 7, 69, 61],
#         [11, 73, 54],
#         [ 8, 76, 48],
#         ...,
#         [13, 54, 10],
#         [18, 59, 12],
#         [ 8, 70, 14]],
#
#        [[12, 77, 66],
#         [11, 74, 60],
#         [ 8, 76, 55],
#         ...,
#         [13, 46,  9],
#         [21, 77, 15],
#         [12, 85, 19]],
#
#        [[12, 86, 71],
#         [11, 84, 66],
#         [ 9, 78, 60],
#         ...,
#         [10, 33,  9],
#         [10, 54, 11],
#         [ 5, 56, 11]],
#
#        ...,
#
#        [[ 2, 34,  7],
#         [ 3, 27,  5],
#         [ 4, 28,  6],
#         ...,
#         [ 1,  0,  0],
#         [ 1,  0,  0],
#         [ 0,  1,  0]],
#
#        [[ 2, 35,  7],
#         [ 2, 30,  6],
#         [ 5, 27,  5],
#         ...,
#         [ 2,  3,  0],
#         [ 1,  2,  1],
#         [ 0,  0,  0]],
#
#        [[ 3, 35,  7],
#         [ 3, 39,  7],
#         [ 4, 35,  8],
#         ...,
#         [ 0,  1,  0],
#         [ 1,  2,  1],
#         [ 3,  1,  0]]], dtype=uint8)

# %%
img_8bit
# Out:
# array([[[ 7, 69, 61],
#         [11, 73, 54],
#         [ 8, 76, 48],
#         ...,
#         [13, 54, 10],
#         [18, 59, 12],
#         [ 8, 70, 14]],
#
#        [[12, 77, 66],
#         [11, 74, 60],
#         [ 8, 76, 55],
#         ...,
#         [13, 46,  9],
#         [21, 77, 15],
#         [12, 85, 19]],
#
#        [[12, 86, 71],
#         [11, 84, 66],
#         [ 9, 78, 60],
#         ...,
#         [10, 33,  9],
#         [10, 54, 11],
#         [ 5, 56, 11]],
#
#        ...,
#
#        [[ 2, 34,  7],
#         [ 3, 27,  5],
#         [ 4, 28,  6],
#         ...,
#         [ 1,  0,  0],
#         [ 1,  0,  0],
#         [ 0,  1,  0]],
#
#        [[ 2, 35,  7],
#         [ 2, 30,  6],
#         [ 5, 27,  5],
#         ...,
#         [ 2,  3,  0],
#         [ 1,  2,  1],
#         [ 0,  0,  0]],
#
#        [[ 3, 35,  7],
#         [ 3, 39,  7],
#         [ 4, 35,  8],
#         ...,
#         [ 0,  1,  0],
#         [ 1,  2,  1],
#         [ 3,  1,  0]]], dtype=uint8)

# %%
grey_img = cv2.imread("images/Osteosarcoma_01.tif", 0)
img_cv2 = cv2.imread("images/Osteosarcoma_01.tif")

# %%
print(grey_img.shape)
print(img_cv2.shape)
# Out:
# (1104, 1376)
# (1104, 1376, 3)

# %%
plt.imshow(cv2.cvtColor(img_cv2, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(grey_img, cv2.COLOR_BGR2RGB))
