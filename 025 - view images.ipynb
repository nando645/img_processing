# %%
from skimage import io
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
img = io.imread('images/Osteosarcoma_01.tif')
img_gray = io.imread('images/Osteosarcoma_01.tif', as_gray=True)

# %%
io.imshow(img)

# %%
plt.imshow(img_gray, cmap="hot")

# %%
plt.imshow(img_gray, cmap="OrRd")

# %%
arr = np.random.random(100)

# %%
plt.figure(figsize=(10,10)).add_subplot().plot(arr)

# %%
plt.figure(figsize=(10,6))
x_val = [1,2,3,4]
h_val = [3,5,1,6]
plt.bar(x_val, h_val)

plt.xticks(ticks=x_val,
          labels=['Senin', 'Selasa', 'Rabu', 'Kamis'],
          rotation=45,
          fontsize=12)
plt.yticks(ticks=np.arange(10), fontsize=12)
plt.title("Days", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Days')

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=2, ncols=2,
                               sharey=True, figsize=(8,5))
ax1.plot(np.random.random(30))
ax2.plot(np.random.random(30)*5)
ax.plot(np.random.random(30)*6)
ax2.plot(np.random.random(30)*8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [61], line 1
# ----> 1 fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=2, ncols=2,
#       2                                sharey=True, figsize=(8,5))
#       3 ax1.plot(np.random.random(30))
#       4 ax2.plot(np.random.random(30)*5)
#
# ValueError: not enough values to unpack (expected 4, got 2)
